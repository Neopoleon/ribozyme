# %%
import urllib
import glob
import requests
from bs4 import BeautifulSoup
from tqdm import tqdm
import re
import aiohttp
import asyncio

# %%
def get_bprnaID(file):
    return 'bpRNA_' + file.split('bpRNA_')[-1].split('.bpseq')[0]

def get_link(file):
    return 'https://bprna.cgrb.oregonstate.edu/search.php?query=' + get_bprnaID(file)

def get_links(dir):
    files = glob.glob(dir + '/*.bpseq')
    return [get_link(file) for file in files]

# %%
def get_RNA_type(file):
    url = get_link(file)
    response = requests.get(url)
    rna_type = response.text.split('RNA Type:</b>')[1].split('<br>')[0].strip()
    return rna_type

def get_RNA_types(dir):
    files = glob.glob(dir + '/*.bpseq')
    types = []
    for file in tqdm(files):
        try:
            types.append(get_RNA_type(file))
        except:
            types.append(None)
    return types

# %%
advanced_link = 'https://bprna.cgrb.oregonstate.edu/advancedSearch.php'

# %%
links = get_links('/Users/elimeyers/ribozyme/data/unzipped/bpRNA_1m_90_bpseqFiles')

# %%
url = links[0]
requests.get(url)
# Out:
# <Response [200]>

# %%
response =

# %%
url = advanced_link
response = requests.get(url)

# %%
response.text
# Out:
# '<!DOCTYPE html>\n<html lang="en">\n  <head>\n    <meta charset="utf-8">\n    <title>bpRNA: RNA Secondary Structure Database</title>\n    <meta name="viewport" content="width=device-width, initial-scale=1">\n    <meta http-equiv="X-UA-Compatible" content="IE=edge" /> \n    <link rel="stylesheet" href="https://maxcdn.bootstrapcdn.com/bootstrap/3.3.7/css/bootstrap.min.css"> \n    <link rel="stylesheet" href="/css/bootstrap.css" media="screen">\n    <link rel="stylesheet" href="/css/custom.min.css">\n    \n    \n    <script src="https://ajax.googleapis.com/ajax/libs/jquery/3.2.1/jquery.min.js"></script>\n    <script src="https://maxcdn.bootstrapcdn.com/bootstrap/3.3.7/js/bootstrap.min.js"></script>\n    \n\n  </head>\n\n  <body>\n    <style>\n      .hidden{\n      display:none;\n      }\n      \n      .unhidden{\n      display:block;\n      }\n      \n       .popover-title { color: navy; background:#E8E8E8; font-weight:bold; font-size: 16px;}  /* default title color for all popovers */\n       .popover-content { color: black; background:white; font-size: 16px;}\n\n    </style>\n\n\n    <nav class="navbar navbar-default">\n      <div class="container-fluid">\n\t<div class="navbar-header">\n\t  <button type="button" class="navbar-toggle collapsed" data-toggle="collapse" data-target="#bs-example-navbar-collapse-1">\n            <span class="sr-only">Toggle navigation</span>\n            <span class="icon-bar"></span>\n            <span class="icon-bar"></span>\n            <span class="icon-bar"></span>\n\t  </button>\n\t  <a class="navbar-brand" href="/index.html">bpRNA-1m</a>\n\t</div>\n\t\n\t<div class="collapse navbar-collapse" id="bs-example-navbar-collapse-1">\n\t  <ul class="nav navbar-nav">\n\t    \n            <li><a href="/about.php">About</a></li>\n            <li><a href="/advancedSearch.php">Advanced Search</a></li>\n\t    <li class="dropdown">\n\t            <a class="dropdown-toggle" data-toggle="dropdown" href="#">Download\n                <span class="caret"></span></a>\n              <ul class="dropdown-menu">\n                <li><a href="/download.php#bpRNA">bpRNA</a></li>\n                <li><a href="/download.php#bpRNA-1m">bpRNA-1m</a></li>\n                <li><a href="/download.php#bpRNA-1m(90)">bpRNA-1m(90)</a></li>\n              </ul>\n             </li>\n\t  </ul>\n\t  <ul class="nav navbar-nav navbar-right">\n            <li><a href="/help.php">Help</a></li>\n\t  </ul>\n\t</div>\n      </div>\n    </nav>\n\n      \n<div class="container">\n  <div class="row">\n    <span class="input-group-btn" style="width:900px;padding-bottom: 0.5cm; padding-left: 0.8cm;"> \n      <!--<div class="page-header"> -->\n      <h1 id="forms">Advanced Search</h1>\n      <!--</div> -->\n    </span>\n    <span class="input-group-btn">\n      <div  style="padding-right: 0.1cm;" >\n        <p><a class="btn btn-default " id="clearform" type="submit" >Clear</a></p>\n      </div>\n    </span>\n    <span class="input-group-btn">\n      <div  style="padding-right: 0.8cm;" >\n\t<p><a class="btn btn-primary" id="searchform" type="submit">Search</a></p>\n      </div>\n    </span>\n  </div>\n  \n  <form id="mainform" name="mainform">\n    <!-- PANEL 1.1 -->    \n    <div class="col-lg-6">                                                                                                                                            \n      <div class="well bs-component" style="background-color:#f0f0f0;"> \n\t<fieldset>   \n\t  <div class="form-group open">\n\t    <label for="selectref" class="control-label">Reference Database  <a href="#"  data-toggle="popover" title="Database" data-content="The original database that the RNA comes from. <a href=\'/help.php#database\'> More info ... </a>"><span class="glyphicon glyphicon-question-sign"></span></a></label>\n\t    <div class="input-group">\n\t      <span class="input-group-btn" style="width:310px;">\n\t\t<select class="form-control" id="selectref">\n\t\t  <option value="ANY">Any Reference Database ...

# %%
response.text.split('Afu')[0]
options = re.findall(r'<option value="([^"]*)">([^<]*)</option>', response.text)

# %%
ns = [option[0] for option in options]
options[2432]
# Out:
# ('2424', "RNA (5'-R(*GP*AP*UP*CP*UP*CP*UP*UP*GP*UP*AP*GP*AP*UP*CP*A)-3')")

# %%
rna_types = []
for i, n in enumerate(ns):
    if n == str(i - 8):
        rna_types.append(n)

# %%
def make_url(rna_type):
    return f'https://bprna.cgrb.oregonstate.edu/list.php?refDB=ANY&refName=&rnaclass=&organism=&type={rna_type}&seqval=&method=ANY&pubmedid=&pubmedcenteral=&length=ANY&fromlength=&tolength=&seq=&bps=ANY&frombps=&tobps=&unbps=ANY&fromunbps=&tounbps=&noncanonic=ANY&fromnoncanonic=&tononcanonic=&bulgenum=ANY&frombulgenum=&tobulgenum=&bulgelength=ANY&frombulgelength=&tobulgelength=&bulgeseq=&bulgepk=false&hairpinnum=ANY&fromhairpinnumber=&tohairpinnumber=&hairpinlength=ANY&fromhairpinlength=&tohairpinlength=&hairpinseq=&hairpinpk=false&ilsnumber=ANY&fromilsnumber=&toilsnumber=&ilslength=ANY&fromilslength=&toilslength=&ilseq=&ilspk=false&mlsnumber=ANY&frommlsnumber=&tomlsnumber=&mlslength=ANY&frommlslength=&tomlslength=&mlsseq=&mlspk=false&urtype=ANY&urnumber=ANY&fromurnumber=&tournumber=&urlength=ANY&fromurlength=&tourlength=&urseq=&urpk=false&stemnumber=ANY&fromstemnumber=&tostemnumber=&stemlength=ANY&fromstemlength=&tostemlength=&stemseq=&segnumber=ANY&fromsegnum=&tosegnum=&segbps=ANY&fromsegbps=&tosegbps=&stemseqrb5p=true&warningpk=false&pktype2=ANY&pktype1=ANY&topkbps=&frompkbps=&pkbps=ANY&pknumber=ANY&frompknum=&topknum='

# %%
def pretty_print(text):
    soup = BeautifulSoup(text, 'html.parser')
    print(soup.prettify())

# %%
response.text.split('php')
# Out:
# ['<!DOCTYPE html>\n<html lang="en">\n  <head>\n    <meta charset="utf-8"> \n    <title>bpRNA: RNA Secondary Structure Database</title>\n    <meta name="viewport" content="width=device-width, initial-scale=1">\n    <meta http-equiv="X-UA-Compatible" content="IE=edge" />\n    <link rel="stylesheet" href="/css/bootstrap.css" media="screen">\n    <link rel="stylesheet" type="text/css" href="//cdn.datatables.net/1.10.15/css/jquery.dataTables.css"> \n    <!--<link rel="stylesheet" type="text/css" href="/css/jquery_1.10.15.dataTables.css"> -->\n    <script src="/js/jquery_3.3.1.min.js"></script>\n    <script src="/js/bootstrap_3.3.7.min.js"></script>\n\n\n    <!-- HTML5 shim and Respond.js IE8 support of HTML5 elements and media queries -->\n    <!--[if lt IE 9]>\n      <script src="/js/html5shiv.js"></script>\n      <script src="/js/respond.min.js"></script>\n    <![endif]-->\n\n    <style>\n      .table-striped tbody tr:nth-child(odd) td,\n      .table-striped tbody tr:nth-child(odd) th {\n      background-color: #F0F8FF;\n      }\n      div.dataTables_processing { z-index: 1; }\n      \n     #loaderlabel{\n      position: absolute;\n      left: 40%;\n      top: 30%;\n      font-weight:bold;\n      font-size: 40px;\n      color:#2171b5;\n      }\n      \n     #loader {\n      position: absolute;\n      left: 50%;\n      top: 50%;\n      z-index: 1;\n      width: 150px;\n      height: 150px;\n      margin: -75px 0 0 -75px;\n      border: 16px solid #f3f3f3;\n      border-radius: 50%;\n      border-top: 20px solid #eff3ff;\n      border-right: 20px solid #bdd7e7;\n      border-bottom: 20px solid #6baed6;\n      border-left: 20px solid #2171b5;\n\n      -webkit-animation: spin 2s linear infinite;\n      animation: spin 2s linear infinite;\n      }\n      \n      @-webkit-keyframes spin {\n      0% { -webkit-transform: rotate(0deg); }\n      100% { -webkit-transform: rotate(360deg); }\n      }\n      \n      @keyframes spin {\n      0% { transform: rotate(0deg); }\n      100% { transform: rotate(360deg); }\n      }\n\n      /* Add animation to "page content" */\n      .animate-bottom {\n      position: relative;\n      -webkit-animation-name: animatebottom;\n      -webkit-animation-duration: 1s;\n      animation-name: animatebottom;\n      animation-duration: 1s\n      }\n      \n      @-webkit-keyframes animatebottom {\n      from { bottom:-100px; opacity:0 } \n      to { bottom:0px; opacity:1 }\n      }\n      \n      @keyframes animatebottom { \n      from{ bottom:-100px; opacity:0 } \n      to{ bottom:0; opacity:1 }\n      }\n      \n      #myDiv {\n      display: none;\n      text-align: center;\n    </style>\n\n  </head>\n\n  <body>\n    <nav class="navbar navbar-default">\n      <div class="container-fluid">\n\t<div class="navbar-header">\n\t  <button type="button" class="navbar-toggle collapsed" data-toggle="collapse" data-target="#bs-example-navbar-collapse-1">\n            <span class="sr-only">Toggle navigation</span>\n            <span class="icon-bar"></span>\n            <span class="icon-bar"></span>\n            <span class="icon-bar"></span>\n\t  </button>\n\t  <a class="navbar-brand" href="/index.html">bpRNA-1m</a>\n\t</div>\n\t\n\t<div class="collapse navbar-collapse" id="bs-example-navbar-collapse-1">\n\t  <ul class="nav navbar-nav">\n\t    \n            <li><a href="/about.',
#  '">About</a></li>\n            <li><a href="/advancedSearch.',
#  '">Advanced Search</a></li>\n\t    <li class="dropdown">\n\t            <a class="dropdown-toggle" data-toggle="dropdown" href="#">Download\n                <span class="caret"></span></a>\n              <ul class="dropdown-menu">\n                <li><a href="/download.',
#  '#bpRNA">bpRNA</a></li>\n                <li><a href="/download.',
#  '#bpRNA-1m">bpRNA-1m</a></li>\n                <li><a href="/download.',
#  '#bpRNA-1m(90)">bpRNA-1m(90)</a></li>\n              </ul>\n             </li>\n\n\n\t  </ul>\n\t  <ul class="nav navbar-nav navbar-right">\n            <li><a href="/help.',
#  '">Help</a></li>\n\t  </ul>\n\t</div>\n      </div>\n    </nav>\n  \n\n    <div id="wrap">\n      <div class="container">\n\n\t<h3>   </h3>    \n\t<table id="test" cellpadding="0" cellspacing="0" border="0" class="datatable table table-striped  table-hover">\n\t  <thead>\n\t    <tr>\n\t      <th>bpRNA ID</th>\n\t      <th>Length</th>\n\t      <th>Unpaired Bases</th>\n\t      <th>Paired Bases</th>\n\t      <th>Origin Name</th>\n\t      <th>Domain</th>\n\t      <th>Organism</th>\n\t      <th>Database</th>\n\t      <th>Origin URL</th>\n\t      \n\t    </tr>\n\t  </thead>\n\t  <tbody>\n\t  <tr>\n            <th>...</th>\n            <th>...</th>\n            <th>...</th>\n            <th>...</th>\n            <th>...</th>\n            <th>...</th>\n            <th>...</th>\n            <th>...</th>\n            <th>...</th>\n          </tr>\n\t  \n\t  <!-- </tbody> -->\n\n\n\t</table>\n\n\t\n\t<div id="loader"  class="modal" style="display:none;"  data-backdrop="static" data-keyboard="false"> \n\t</div> \n\n\t<div id="loaderlabel"  style="display:none;">\n          <p>Please Wait ...</p>\n        </div>\t\n\t\n\t</br>\n\n              <div class="form-group open">\n\t\t<div class="input-group">\n\t\t  <span class="input-group-btn" style="width:310px;">\n\t\t    <select class="form-control" id="downloadtype">\n                      <option value="fasta">Fasta Files</option>\n                      <option value="ct">CT Files</option>\n                      <option value="bpseq">BPSeq Files</option>\n                      <option value="dbn">Dot Bracket Files</option>\n                      <option value="st">Structure Types Files</option>\n                      <option value="sta">Structure Types Array Files</option>\n\t\t      <!--<option value="jpg">JPG Files</option>\n\t\t      <option value="pdf">PDF Files</option> -->\n                    </select>\n\t\t  </span>\n\t\t  &nbsp;\n\t\t  <span class="input-group-btn" style="width:310px;">\n                    <a class="btn btn-primary" id="downloadbtn" onclick="zipAndDownload()">DOWNLOAD</a>\n\t\t  </span>\n\t\t</div>\n\t      </div>\n\t\n\n\n\t<script src="https://ajax.googleapis.com/ajax/libs/jquery/2.1.3/jquery.min.js"></script>\n\t<script src="//netdna.bootstrapcdn.com/bootstrap/3.0.0/js/bootstrap.min.js"></script>\n\t<script type = "text/javascript">\n\t function deleteZipFile (filename) {\n\t  $.ajax( { type : \'POST\',\n                 data : { filname:filename},\n                 url  : \'scripts/deletezip.',
#  '\',\n                 dataType:\'text\',\n                 success: function(data)\n                 {\n                   data=JSON.stringify(data);\n                   //alert(data);\n                 },\n                 error: function ( xhr ) {\n                   //alert( "error" );\n                 }\n\n               });\n\t  } \n\t  \n\t  function zipAndDownload () {\n\t  $(\'#loaderlabel\').show();\n\t  $(\'#loader\').modal(\'show\');\n\t  $.ajax( { type : \'POST\',\n\t  data : { downloadtype:$("#downloadtype").val()},\n\t  url  : \'scripts/makezip.',
#  '\',\n\t  dataType:\'text\',\n\t  success: function(data)\n\t  {\n\t  data=JSON.stringify(data);\n\t  //alert(data);\n\t  var word = "ZIPFILES";\n\t  var myString = data.substr(data.indexOf(word) + word.length + 5);\n\t  myString = myString.substr(0,myString.length-4);\n\t  location.href = myString;\n\t  var pattern1 = "temp";\n\t  filename=myString.substr(myString.indexOf(pattern1)+7 , myString.length);\n\t  $(\'#loaderlabel\').hide();\n\t  $(\'#loader\').modal(\'hide\');\n\t  setInterval(function() {\n         \t deleteZipFile(filename);\n         }, 1000);\n\t  },\n\t  error: function ( xhr ) {\n\t  alert( "Time Out!" );\n\t  }\n\t  \n          });\n          }\n\t</script>\n\t\n\n\n\n\n\t\n      </div>\n\n      \n    </div>\n\n    <script src="//ajax.googleapis.com/ajax/libs/jquery/1.10.2/jquery.min.js"></script>\n    <script src="//cdnjs.cloudflare.com/ajax/libs/datatables/1.9.4/jquery.dataTables.min.js"></script>\n    <script src="//netdna.bootstrapcdn.com/bootstrap/3.0.0/js/bootstrap.min.js"></script>\n    <script type="text/javascript" charset="utf8" src="//cdn.datatables.net/1.10.15/js/jquery.dataTables.js"></script> \n\n\n\n    \n    <script type="text/javascript" class="init">\n      jQuery.noConflict()(function ($) {\n      $(document).ready(function() {\n      $(\'.datatable\').dataTable({\n      "deferRender": true,\n      "serverSide": true,\n      "processing": true,\n      "ajax": "scripts/server_processing.',
#  '",\n      "PaginationType": "bs_four_button",\n      "oLanguage": {\n      "sZeroRecords": "No records to display"\n      },\n      "aoColumnDefs":[{\n      "sTitle":"bpRNA ID"\n      , "aTargets": [ "rna_Name" ]\n      },{\n      "aTargets": [ 0 ]\n      , "bSortable": true\n      , "mRender": function ( url, type, full )  {\n      return  \'<a target = "_blank"  href="search.',
#  '?query=\'+url+\'">\' + url + \'</a>\';\n      }\n      },{\n        "aTargets": [ 8 ]\n      , "bSortable": false\n      , "mRender": function ( url, type, full )  {\n          return  \'<a target = "_blank"  href="\'+url+\'">\' + url + \'</a>\';\n      }\n      }]\n\n\n\t\n      });\n\t});\n\t\n      $(\'.datatable\').each(function(){\n      var datatable = $(this);\n         // SEARCH - Add the placeholder for Search and Turn this into in-line form control\n      var search_input = datatable.closest(\'.dataTables_wrapper\').find(\'div[id$=_filter] input\');\n      search_input.attr(\'placeholder\', \'Search\');\n      search_input.addClass(\'form-control input-sm\');\n      // LENGTH - Inline-Form control\n      var length_sel = datatable.closest(\'.dataTables_wrapper\').find(\'div[id$=_length] select\');\n      length_sel.addClass(\'form-control input-sm\');\n      });\n      });\n     //});\n      \n    </script>\n\n\n\n\n  </body>\n</html>\n']

# %%
url = make_url(2)
response = requests.get(url)
pretty_print(response.text)
# rnas = re.findall(r'bpRNA__([0-9]+)', response.text)
# response.text.split('Archaea')
# Out:
# <!DOCTYPE html>
# <html lang="en">
#  <head>
#   <meta charset="utf-8"/>
#   <title>
#    bpRNA: RNA Secondary Structure Database
#   </title>
#   <meta content="width=device-width, initial-scale=1" name="viewport"/>
#   <meta content="IE=edge" http-equiv="X-UA-Compatible">
#    <link href="/css/bootstrap.css" media="screen" rel="stylesheet"/>
#    <link href="//cdn.datatables.net/1.10.15/css/jquery.dataTables.css" rel="stylesheet" type="text/css"/>
#    <!--<link rel="stylesheet" type="text/css" href="/css/jquery_1.10.15.dataTables.css"> -->
#    <script src="/js/jquery_3.3.1.min.js">
#    </script>
#    <script src="/js/bootstrap_3.3.7.min.js">
#    </script>
#    <!-- HTML5 shim and Respond.js IE8 support of HTML5 elements and media queries -->
#    <!--[if lt IE 9]>
#       <script src="/js/html5shiv.js"></script>
#       <script src="/js/respond.min.js"></script>
#     <![endif]-->
#    <style>
#     .table-striped tbody tr:nth-child(odd) td,
#       .table-striped tbody tr:nth-child(odd) th {
#       background-color: #F0F8FF;
#       }
#       div.dataTables_processing { z-index: 1; }
#
#      #loaderlabel{
#       position: absolute;
#       left: 40%;
#       top: 30%;
#       font-weight:bold;
#       font-size: 40px;
#       color:#2171b5;
#       }
#
#      #loader {
#       position: absolute;
#       left: 50%;
#       top: 50%;
#       z-index: 1;
#       width: 150px;
#       height: 150px;
#       margin: -75px 0 0 -75px;
#       border: 16px solid #f3f3f3;
#       border-radius: 50%;
#       border-top: 20px solid #eff3ff;
#       border-right: 20px solid #bdd7e7;
#       border-bottom: 20px solid #6baed6;
#       border-left: 20px solid #2171b5;
#
#       -webkit-animation: spin 2s linear infinite;
#       animation: spin 2s linear infinite;
#       }
#
#       @-webkit-keyframes spin {
#       0% { -webkit-transform: rotate(0deg); }
#       100% { -webkit-transform: rotate(360deg); }
#       }
#
#       @keyframes spin {
#       0% { transform: rotate(0deg); }
#       100% { transform: rotate(360deg); }
#       }
#
#       /* Add animation to "page content" */
#       .animate-bottom {
#       position: relative;
#       -webkit-animation-name: animatebottom;
#       -webkit-animation-duration: 1s;
#       animation-name: animatebottom;
#       animation-duration: 1s
#       }
#
#       @-webkit-keyframes animatebottom {
#       from { bottom:-100px; opacity:0 }
#       to { bottom:0px; opacity:1 }
#       }
#
#       @keyframes animatebottom {
#       from{ bottom:-100px; opacity:0 }
#       to{ bottom:0; opacity:1 }
#       }
#
#       #myDiv {
#       display: none;
#       text-align: center;
#    </style>
#   </meta>
#  </head>
#  <body>
#   <nav class="navbar navbar-default">
#    <div class="container-fluid">
#     <div class="navbar-header">
#      <button class="navbar-toggle collapsed" data-target="#bs-example-navbar-collapse-1" data-toggle="collapse" type="button">
#       <span class="sr-only">
#        Toggle navigation
#       </span>
#       <span class="icon-bar">
#       </span>
#       <span class="icon-bar">
#       </span>
#       <span class="icon-bar">
#       </span>
#      </button>
#      <a class="navbar-brand" href="/index.html">
#       bpRNA-1m
#      </a>
#     </div>
#     <div class="collapse navbar-collapse" id="bs-example-navbar-collapse-1">
#      <ul class="nav navbar-nav">
#       <li>
#        <a href="/about.php">
#         About
#        </a>
#       </li>
#       <li>
#        <a href="/advancedSearch.php">
#         Advanced Search
#        </a>
#       </li>
#       <li class="dropdown">
#        <a class="dropdown-toggle" data-toggle="dropdown" href="#">
#         Download
#         <span class="caret">
#         </span>
#        </a>
#        <ul class="dropdown-menu">
#         <li>
#          <a href="/download.php#bpRNA">
#           bpRNA
#          </a>
#         </li>
#         <li>
#          <a href="/download.php#bpRNA-1m">
#           bpRNA-1m
#          </a>
#         </li>
#         <li>
#          <a href="/download.php#bpRNA-1m(90)">
#           bpRNA-1m(90)
#          </a>
#         </li>
#        </ul>
#       </li>
#      </ul>
#      <ul class="nav navbar-nav navbar-right">
#       <li>
#        <a href="/help.php">
#         Help
#        </a>
#       </li>
#      </ul>
#     </div>
#    </div>
#   </nav>
#   <div id="wrap">
#    <div class="container">
#     <h3>
#     </h3>
#     <table border="0" cellpadding="0" cellspacing="0" class="datatable table table-striped table-hover" id="test">
#      <thead>
#       <tr>
#        <th>
#         bpRNA ID
#        </th>
#        <th>
#         Length
#        </th>
#        <th>
#         Unpaired Bases
#        </th>
#        <th>
#         Paired Bases
#        </th>
#        <th>
#         Origin Name
#        </th>
#        <th>
#         Domain
#        </th>
#        <th>
#         Organism
#        </th>
#        <th>
#         Database
#        </th>
#        <th>
#         Origin URL
#        </th>
#       </tr>
#      </thead>
#      <tbody>
#       <tr>
#        <th>
#         ...
#        </th>
#        <th>
#         ...
#        </th>
#        <th>
#         ...
#        </th>
#        <th>
#         ...
#        </th>
#        <th>
#         ...
#        </th>
#        <th>
#         ...
#        </th>
#        <th>
#         ...
#        </th>
#        <th>
#         ...
#        </th>
#        <th>
#         ...
#        </th>
#       </tr>
#       <!-- </tbody> -->
#      </tbody>
#     </table>
#     <div class="modal" data-backdrop="static" data-keyboard="false" id="loader" style="display:none;">
#     </div>
#     <div id="loaderlabel" style="display:none;">
#      <p>
#       Please Wait ...
#      </p>
#     </div>
#     <div class="form-group open">
#      <div class="input-group">
#       <span class="input-group-btn" style="width:310px;">
#        <select class="form-control" id="downloadtype">
#         <option value="fasta">
#          Fasta Files
#         </option>
#         <option value="ct">
#          CT Files
#         </option>
#         <option value="bpseq">
#          BPSeq Files
#         </option>
#         <option value="dbn">
#          Dot Bracket Files
#         </option>
#         <option value="st">
#          Structure Types Files
#         </option>
#         <option value="sta">
#          Structure Types Array Files
#         </option>
#         <!--<option value="jpg">JPG Files</option>
# 		      <option value="pdf">PDF Files</option> -->
#        </select>
#       </span>
#       <span class="input-group-btn" style="width:310px;">
#        <a class="btn btn-primary" id="downloadbtn" onclick="zipAndDownload()">
#         DOWNLOAD
#        </a>
#       </span>
#      </div>
#     </div>
#     <script src="https://ajax.googleapis.com/ajax/libs/jquery/2.1.3/jquery.min.js">
#     </script>
#     <script src="//netdna.bootstrapcdn.com/bootstrap/3.0.0/js/bootstrap.min.js">
#     </script>
#     <script type="text/javascript">
#      function deleteZipFile (filename) {
# 	  $.ajax( { type : 'POST',
#                  data : { filname:filename},
#                  url  : 'scripts/deletezip.php',
#                  dataType:'text',
#                  success: function(data)
#                  {
#                    data=JSON.stringify(data);
#                    //alert(data);
#                  },
#                  error: function ( xhr ) {
#                    //alert( "error" );
#                  }
#
#                });
# 	  }
#
# 	  function zipAndDownload () {
# 	  $('#loaderlabel').show();
# 	  $('#loader').modal('show');
# 	  $.ajax( { type : 'POST',
# 	  data : { downloadtype:$("#downloadtype").val()},
# 	  url  : 'scripts/makezip.php',
# 	  dataType:'text',
# 	  success: function(data)
# 	  {
# 	  data=JSON.stringify(data);
# 	  //alert(data);
# 	  var word = "ZIPFILES";
# 	  var myString = data.substr(data.indexOf(word) + word.length + 5);
# 	  myString = myString.substr(0,myString.length-4);
# 	  location.href = myString;
# 	  var pattern1 = "temp";
# 	  filename=myString.substr(myString.indexOf(pattern1)+7 , myString.length);
# 	  $('#loaderlabel').hide();
# 	  $('#loader').modal('hide');
# 	  setInterval(function() {
#          	 deleteZipFile(filename);
#          }, 1000);
# 	  },
# 	  error: function ( xhr ) {
# 	  alert( "Time Out!" );
# 	  }
#
#           });
#           }
#     </script>
#    </div>
#   </div>
#   <script src="//ajax.googleapis.com/ajax/libs/jquery/1.10.2/jquery.min.js">
#   </script>
#   <script src="//cdnjs.cloudflare.com/ajax/libs/datatables/1.9.4/jquery.dataTables.min.js">
#   </script>
#   <script src="//netdna.bootstrapcdn.com/bootstrap/3.0.0/js/bootstrap.min.js">
#   </script>
#   <script charset="utf8" src="//cdn.datatables.net/1.10.15/js/jquery.dataTables.js" type="text/javascript">
#   </script>
#   <script class="init" type="text/javascript">
#    jQuery.noConflict()(function ($) {
#       $(document).ready(function() {
#       $('.datatable').dataTable({
#       "deferRender": true,
#       "serverSide": true,
#       "processing": true,
#       "ajax": "scripts/server_processing.php",
#       "PaginationType": "bs_four_button",
#       "oLanguage": {
#       "sZeroRecords": "No records to display"
#       },
#       "aoColumnDefs":[{
#       "sTitle":"bpRNA ID"
#       , "aTargets": [ "rna_Name" ]
#       },{
#       "aTargets": [ 0 ]
#       , "bSortable": true
#       , "mRender": function ( url, type, full )  {
#       return  '<a target = "_blank"  href="search.php?query='+url+'">' + url + '</a>';
#       }
#       },{
#         "aTargets": [ 8 ]
#       , "bSortable": false
#       , "mRender": function ( url, type, full )  {
#           return  '<a target = "_blank"  href="'+url+'">' + url + '</a>';
#       }
#       }]
#
#
#
#       });
# 	});
#
#       $('.datatable').each(function(){
#       var datatable = $(this);
#          // SEARCH - Add the placeholder for Search and Turn this into in-line form control
#       var search_input = datatable.closest('.dataTables_wrapper').find('div[id$=_filter] input');
#       search_input.attr('placeholder', 'Search');
#       search_input.addClass('form-control input-sm');
#       // LENGTH - Inline-Form control
#       var length_sel = datatable.closest('.dataTables_wrapper').find('div[id$=_length] select');
#       length_sel.addClass('form-control input-sm');
#       });
#       });
#      //});
#   </script>
#  </body>
# </html>

# %%
session = requests.Session()
session.headers.update({
    "User-Agent": "Mozilla/5.0",  # mimic browser
})

ajax_url = "https://bprna.cgrb.oregonstate.edu/<whatever-you-found>.php"

params_or_data = {
    # copy from DevTools (this is just an example)
    "rnaclass": "tRNA",   # or whatever encodes RNA type
    "type": "2",
    # maybe paging options, etc.
}

r = session.get(ajax_url, params=params_or_data)  # or .post(...)
r.raise_for_status()

# If JSON:
# data = r.json()
# If HTML:
from bs4 import BeautifulSoup
soup = BeautifulSoup(r.text, "html.parser")

rows = soup.find_all("tr")
bprna_ids = []
for row in rows:
    cols = [c.get_text(strip=True) for c in row.find_all("td")]
    if cols:
        bprna_ids.append(cols[0])

print(bprna_ids)
# Out:
# 200
# <!DOCTYPE html>
# <html lang="en">
#   <head>
#     <meta charset="utf-8">
#     <title>bpRNA: RNA Secondary Structure Database</title>
#     <meta name="viewport" content="width=device-width, initial-scale=1">
#     <meta http-equiv="X-UA-Compatible" content="IE=edge" />
#     <link rel="stylesheet" href="/css/bootstrap.css" media="screen">
#     <link rel="stylesheet" type="text/css" href="//cdn.datatables.net/1.10.15/css/jquery.dataTables.css">
#     <!--<link rel="stylesheet" type="text/css" href="/css/jquery_1.10.15.dataTables.css"> -->
#     <script src="/js/jquery_3.3.1.min.js"></script>
#     <script src="/js/bootstrap_3.3.7.min.js"></script>
#
#
#     <!-- HTML5 shim and Respond.js IE8 support of HTML5 elements and media queries -->
#     <!--[if lt IE 9]>
#       <script src="/js/html5shiv.js"></script>
#       <script src="/js/respond.min.js"></script>
#     <![endif]-->
#
#     <style>
#       .table-striped tbody tr:nth-child(odd) td,
#       .table-striped tbody tr:nth-child(odd) th {
#       background-color: #F0F8FF;
#       }
#       div.dataTables_processing { z-index: 1; }
#
#      #loaderlabel{
#       position: absolute;
#       left: 40%;
#       top: 30%;
#       font-weight:bold;
#       font-size: 40px;
#       color:#2171b5;
#       }
#
#      #loader {
#       position: absolute;
#       left: 50%;
#       top: 50%;
#       z-index: 1;
#       width: 150px;
#       height: 150px;
#       margin: -75px 0 0 -75px;
#       border: 16px solid #f3f3f3;
#       border-radius: 50%;
#       border-top: 20px solid #eff3ff;
#       border-right: 20px solid #bdd7e7;
#       border-bottom: 20px solid #6baed6;
#       border-left: 20px solid #2171b5;
#
#       -webkit-animation: spin 2s linear infinite;
#       animation: spin 2s linear infinite;
#       }
#
#       @-webkit-keyframes spin {
#       0% { -webkit-transform: rotate(0deg); }
#       100% { -webkit-transform: rotate(360deg); }
#       }
#
#       @keyframes spin {
#       0% { transform: rotate(0deg); }
#       100% { transform: rotate(360deg); }
#       }
#
#       /* Add animation to "page content" */
#       .animate-bottom {
#       position: relative;
#       -webkit-animation-name: animatebottom;
#       -webkit-animation-duration: 1s;
#       animation-name: animatebottom;
#       animation-duration: 1s
#       }
#
#       @-webkit-keyframes animatebottom {
#       from { bottom:-100px; opacity:0 }
#       to { bottom:0px; opacity:1 }
#       }
#
#       @keyframes animatebottom {
#       from{ bottom:-100px; opacity:0 }
#       to{ bottom:0; opacity:1 }
#       }
#
#       #myDiv {
#       display: none;
#       text-align: center;
#     </style>
#
#   </head>
#
#   <body>
#     <nav class="navbar navbar-default">
#       <div class="container-fluid">
# 	<div class="navbar-header">
# 	  <button type="button" class="navbar-toggle collapsed" data-toggle="collapse" data-target="#bs-example-navbar-collapse-1">
#             <span class="sr-only">Toggle navigation</span>
#             <span class="icon-bar"></span>
#             <span class="icon-bar"></span>
#             <span class="icon-bar"></span>
# 	  </button>
# 	  <a class="navbar-brand" href="/index.html">bpRNA-1m</a>
# 	</div>
#
# 	<div class="collapse navbar-collapse" id="bs-example-navbar-collapse-1">
# 	  <ul class="nav navbar-nav">
#
#             <li><a href="/about.php">About</a></li>
#             <li><a href="/advancedSearch.php">Advanced Search</a></li>
# 	    <li class="dropdown">
# 	            <a class="dropdown-toggle" data-toggle="dropdown" href="#">Download
#                 <span class="caret"></span></a>
#               <ul class="dropdown-menu">
#                 <li><a href="/download.php#bpRNA">bpRNA</a></li>
#                 <li><a href="/download.php#bpRNA-1m">bpRNA-1m</a></li>
#                 <li><a href="/download.php#bpRNA-1m(90)">bpRNA-1m(90)</a></li>
#               </ul>
#              </li>
#
#
# 	  </ul>
# 	  <ul class="nav navbar-nav navbar-right">
#             <li><a href="/help.php">Help</a></li>
# 	  </ul>
# 	</div>
#       </div>
#     </nav>
#
#
#     <div id="wrap">
#       <div class="container">
#
# 	<h3>   </h3>
# 	<table id="test" cellpadding="0" cellspacing="0" border="0" class="datatable table table-striped  table-hover">
# 	  <thead>
# 	    <tr>
# 	      <th>bpRNA ID</th>
# 	      <th>Length</th>
# 	      <th>Unpaired Bases</th>
# 	      <th>Paired Bases</th>
# 	      <th>Origin Name</th>
# 	      <th>Domain</th>
# 	      <th>Organism</th>
# 	      <th>Database</th>
# 	      <th>Origin URL</th>
#
# 	    </tr>
# 	  </thead>
# 	  <tbody>
# 	  <tr>
#             <th>...</th>
#             <th>...</th>
#             <th>...</th>
#             <th>...</th>
#             <th>...</th>
#             <th>...</th>
#             <th>...</th>
#             <th>...</th>
#             <th>...</th>
#           </tr>
#
# 	  <!-- </tbody> -->
#
#
# 	</table>
#
#
# 	<div id="loader"  class="modal" style="display:none;"  data-backdrop="static" data-keyboard="false">
# 	</div>
#
# 	<div id="loaderlabel"  style="display:none;">
#           <p>Please Wait ...</p>
#         </div>
#
# 	</br>
#
#               <div class="form-group open">
# 		<div class="input-group">
# 		  <span class="input-group-btn" style="width:310px;">
# 		    <select class="form-control" id="downloadtype">
#                       <option value="fasta">Fasta Files</option>
#                       <option value="ct">CT Files</option>
#                       <option value="bpseq">BPSeq Files</option>
#                       <option value="dbn">Dot Bracket Files</option>
#                       <option value="st">Structure Types Files</option>
#                       <option value="sta">Structure Types Array Files</option>
# 		      <!--<option value="jpg">JPG Files</option>
# 		      <option value="pdf">PDF Files</option> -->
#                     </select>
# 		  </span>
# 		  &nbsp;
# 		  <span class="input-group-btn" style="width:310px;">
#                     <a class="btn btn-primary" id="downloadbtn" onclick="zipAndDownload()">DOWNLOAD</a>
# 		  </span>
# 		</div>
# 	      </div>
#
#
#
# 	<script src="https://ajax.googleapis.com/ajax/libs/jquery/2.1.3/jquery.min.js"></script>
# 	<script src="//netdna.bootstrapcdn.com/bootstrap/3.0.0/js/bootstrap.min.js"></script>
# 	<script type = "text/javascript">
# 	 function deleteZipFile (filename) {
# 	  $.ajax( { type : 'POST',
#                  data : { filname:filename},
#                  url  : 'scripts/deletezip.php',
#                  dataType:'text',
#                  success: function(data)
#                  {
#                    data=JSON.stringify(data);
#                    //alert(data);
#                  },
#                  error: function ( xhr ) {
#                    //alert( "error" );
#                  }
#
#                });
# 	  }
#
# 	  function zipAndDownload () {
# 	  $('#loaderlabel').show();
# 	  $('#loader').modal('show');
# 	  $.ajax( { type : 'POST',
# 	  data : { downloadtype:$("#downloadtype").val()},
# 	  url  : 'scripts/makezip.php',
# 	  dataType:'text',
# 	  success: function(data)
# 	  {
# 	  data=JSON.stringify(data);
# 	  //alert(data);
# 	  var word = "ZIPFILES";
# 	  var myString = data.substr(data.indexOf(word) + word.length + 5);
# 	  myString = myString.substr(0,myString.length-4);
# 	  location.href = myString;
# 	  var pattern1 = "temp";
# 	  filename=myString.substr(myString.indexOf(pattern1)+7 , myString.length);
# 	  $('#loaderlabel').hide();
# 	  $('#loader').modal('hide');
# 	  setInterval(function() {
#          	 deleteZipFile(filename);
#          }, 1000);
# 	  },
# 	  error: function ( xhr ) {
# 	  alert( "Time Out!" );
# 	  }
#
#           });
#           }
# 	</script>
#
#
#
#
#
#
#       </div>
#
#
#     </div>
#
#     <script src="//ajax.googleapis.com/ajax/libs/jquery/1.10.2/jquery.min.js"></script>
#     <script src="//cdnjs.cloudflare.com/ajax/libs/datatables/1.9.4/jquery.dataTables.min.js"></script>
#     <script src="//netdna.bootstrapcdn.com/bootstrap/3.0.0/js/bootstrap.min.js"></script>
#     <script type="text/javascript" charset="utf8" src="//cdn.datatables.net/1.10.15/js/jquery.dataTables.js"></script>
#
#
#
#
#     <script type="text/javascript" class="init">
#       jQuery.noConflict()(function ($) {
#       $(document).ready(function() {
#       $('.datatable').dataTable({
#       "deferRender": true,
#       "serverSide": true,
#       "processing": true,
#       "ajax": "scripts/server_processing.php",
#       "PaginationType": "bs_four_button",
#       "oLanguage": {
#       "sZeroRecords": "No records to display"
#       },
#       "aoColumnDefs":[{
#       "sTitle":"bpRNA ID"
#       , "aTargets": [ "rna_Name" ]
#       },{
#       "aTargets": [ 0 ]
#       , "bSortable": true
#       , "mRender": function ( url, type, full )  {
#       return  '<a target = "_blank"  href="search.php?query='+url+'">' + url + '</a>';
#       }
#       },{
#         "aTargets": [ 8 ]
#       , "bSortable": false
#       , "mRender": function ( url, type, full )  {
#           return  '<a target = "_blank"  href="'+url+'">' + url + '</a>';
#       }
#       }]
#
#
#
#       });
# 	});
#
#       $('.datatable').each(function(){
#       var datatable = $(this);
#          // SEARCH - Add the placeholder for Search and Turn this into in-line form control
#       var search_input = datatable.closest('.dataTables_wrapper').find('div[id$=_filter] input');
#       search_input.attr('placeholder', 'Search');
#       search_input.addClass('form-control input-sm');
#       // LENGTH - Inline-Form control
#       var length_sel = datatable.closest('.dataTables_wrapper').find('div[id$=_length] select');
#       length_sel.addClass('form-control input-sm');
#       });
#       });
#      //});
#
#     </script>
#
#
#
#
#   </body>
# </html>
# /Users/elimeyers/miniconda3/envs/ribozyme/lib/python3.12/site-packages/urllib3/connectionpool.py:1097: InsecureRequestWarning: Unverified HTTPS request is being made to host 'bprna.cgrb.oregonstate.edu'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(

# %%
url
# Out:
# 'https://bprna.cgrb.oregonstate.edu/list.php?refDB=ANY&refName=&rnaclass=&organism=&type=2&seqval=&method=ANY&pubmedid=&pubmedcenteral=&length=ANY&fromlength=&tolength=&seq=&bps=ANY&frombps=&tobps=&unbps=ANY&fromunbps=&tounbps=&noncanonic=ANY&fromnoncanonic=&tononcanonic=&bulgenum=ANY&frombulgenum=&tobulgenum=&bulgelength=ANY&frombulgelength=&tobulgelength=&bulgeseq=&bulgepk=false&hairpinnum=ANY&fromhairpinnumber=&tohairpinnumber=&hairpinlength=ANY&fromhairpinlength=&tohairpinlength=&hairpinseq=&hairpinpk=false&ilsnumber=ANY&fromilsnumber=&toilsnumber=&ilslength=ANY&fromilslength=&toilslength=&ilseq=&ilspk=false&mlsnumber=ANY&frommlsnumber=&tomlsnumber=&mlslength=ANY&frommlslength=&tomlslength=&mlsseq=&mlspk=false&urtype=ANY&urnumber=ANY&fromurnumber=&tournumber=&urlength=ANY&fromurlength=&tourlength=&urseq=&urpk=false&stemnumber=ANY&fromstemnumber=&tostemnumber=&stemlength=ANY&fromstemlength=&tostemlength=&stemseq=&segnumber=ANY&fromsegnum=&tosegnum=&segbps=ANY&fromsegbps=&tosegbps=&stemseqrb5p=true&warningpk=false&pktype2=ANY&pktype1=ANY&topkbps=&frompkbps=&pkbps=ANY&pknumber=ANY&frompknum=&topknum='

# %%
session = requests.Session()
session.headers.update({
    "User-Agent": "Mozilla/5.0",  # mimic browser
})

ajax_url = "https://bprna.cgrb.oregonstate.edu/list.php"

params_or_data = {
    # copy from DevTools (this is just an example)
    "rnaclass": "tRNA",   # or whatever encodes RNA type
    "type": "2",
    # maybe paging options, etc.
}

r = session.get(ajax_url, params=params_or_data)  # or .post(...)
r.raise_for_status()

# If JSON:
# data = r.json()
# If HTML:
from bs4 import BeautifulSoup
soup = BeautifulSoup(r.text, "html.parser")

rows = soup.find_all("tr")
bprna_ids = []
for row in rows:
    cols = [c.get_text(strip=True) for c in row.find_all("td")]
    if cols:
        bprna_ids.append(cols[0])

print(bprna_ids)
# Out:
# []

# %%
r.url
# Out:
# 'https://bprna.cgrb.oregonstate.edu/list.php?rnaclass=tRNA&type=2'

# %%
url
# Out:
# 'https://bprna.cgrb.oregonstate.edu/list.php'

# %%
make_url(1)
# Out:
# 'https://bprna.cgrb.oregonstate.edu/list.php?refDB=ANY&refName=&rnaclass=&organism=&type=1&seqval=&method=ANY&pubmedid=&pubmedcenteral=&length=ANY&fromlength=&tolength=&seq=&bps=ANY&frombps=&tobps=&unbps=ANY&fromunbps=&tounbps=&noncanonic=ANY&fromnoncanonic=&tononcanonic=&bulgenum=ANY&frombulgenum=&tobulgenum=&bulgelength=ANY&frombulgelength=&tobulgelength=&bulgeseq=&bulgepk=false&hairpinnum=ANY&fromhairpinnumber=&tohairpinnumber=&hairpinlength=ANY&fromhairpinlength=&tohairpinlength=&hairpinseq=&hairpinpk=false&ilsnumber=ANY&fromilsnumber=&toilsnumber=&ilslength=ANY&fromilslength=&toilslength=&ilseq=&ilspk=false&mlsnumber=ANY&frommlsnumber=&tomlsnumber=&mlslength=ANY&frommlslength=&tomlslength=&mlsseq=&mlspk=false&urtype=ANY&urnumber=ANY&fromurnumber=&tournumber=&urlength=ANY&fromurlength=&tourlength=&urseq=&urpk=false&stemnumber=ANY&fromstemnumber=&tostemnumber=&stemlength=ANY&fromstemlength=&tostemlength=&stemseq=&segnumber=ANY&fromsegnum=&tosegnum=&segbps=ANY&fromsegbps=&tosegbps=&stemseqrb5p=true&warningpk=false&pktype2=ANY&pktype1=ANY&topkbps=&frompkbps=&pkbps=ANY&pknumber=ANY&frompknum=&topknum='
